# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-50,50,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(6,x)
zz=scipy.special.jv(5,x)
yy=scipy.special.jv(9,x)
ww=scipy.special.jv(8,x)

www=scipy.special.jv(4,x)*(-1)

u=scipy.special.jv(4,x)
v=scipy.special.jv(5,x)

o=scipy.special.jv(1,x)
p=scipy.special.jv(6,x)*(-1)

plt.plot(y,zz,c='w')
plt.plot(v,u,c='r',linewidth=0.7)
plt.plot(yy,ww,c='k')
plt.plot(yy,www)
plt.plot(o,p,linewidth=0.5)
plt.axis('off')
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-40,40,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(3,x)
zz=scipy.special.jv(5,x)

yy=scipy.special.jv(9,-x)
zzz=scipy.special.jv(7,x)


v=scipy.special.jv(7,x)
u=scipy.special.jv(9,x)

ww=scipy.special.jv(5,x)
www=scipy.special.jv(9,x)






plt.plot(y,zz,c='r')
plt.plot(y,z)
plt.plot(yy,zzz,linewidth=0.7)

plt.axis('off')
plt.savefig("D:/temp8.png")
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-50,50,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(6,x)
zz=scipy.special.jv(5,x)
yy=scipy.special.jv(9,x)
ww=scipy.special.jv(8,x)

www=scipy.special.jv(6,x)*(-1)

u=scipy.special.jv(4,x)
v=scipy.special.jv(5,x)

o=scipy.special.jv(1,x)
p=scipy.special.jv(6,x)*(-1)

vv=scipy.special.jv(2,x)*(-1)-0.1
uu=scipy.special.jv(7,x)

plt.plot(y,zz,c='w')
plt.plot(v,u,c='r',linewidth=0.7)
plt.plot(yy,ww,c='k')
plt.plot(yy,www)

plt.plot(o,p,linewidth=0.5)
plt.plot(yy,-u,linewidth=0.3, c='g')

plt.savefig("D:/butter3.png")
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-20,20,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(6,x)
zz=scipy.special.jv(5,x)
yy=scipy.special.jv(9,x)
ww=scipy.special.jv(8,x)

www=scipy.special.jv(6,x)*(-1)

u=scipy.special.jv(4,x)
v=scipy.special.jv(5,x)

o=scipy.special.jv(1,x)
p=scipy.special.jv(6,x)*(-1)

vv=scipy.special.jv(2,x)*(-1)-0.1
uu=scipy.special.jv(7,x)

plt.plot(y,zz,c='w')
plt.plot(v,u,c='r',linewidth=0.7)
plt.plot(yy,ww,c='k')
plt.plot(yy,www)
plt.plot(uu,vv,c='violet',linewidth=0.7)

plt.plot(o,p,linewidth=0.7)
plt.plot(yy,-u,linewidth=0.7, c='g')

plt.savefig("D:/butter.png")

plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-50,50,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(6,x)
zz=scipy.special.jv(5,x)
yy=scipy.special.jv(9,x)
ww=scipy.special.jv(8,x)

www=scipy.special.jv(6,x)*(-1)

u=scipy.special.jv(4,x)
v=scipy.special.jv(5,x)

o=scipy.special.jv(1,x)
p=scipy.special.jv(6,x)*(-1)

vv=scipy.special.jv(2,x)*(-1)-0.1
uu=scipy.special.jv(7,x)

plt.plot(y,zz,c='w')
plt.plot(v,u,c='r',linewidth=0.7)
plt.plot(yy,ww,c='k')
plt.plot(yy,www)
plt.plot(uu,vv,c='violet',linewidth=0.3)

plt.plot(o,p,linewidth=0.5)
plt.plot(yy,-u,linewidth=0.3,c='g')


plt.savefig("D:/butter1.png")
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-30,30,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(3,x)
zz=scipy.special.jv(5,x)

yy=scipy.special.jv(9,-x)
zzz=scipy.special.jv(7,x)


v=scipy.special.jv(7,x)
u=scipy.special.jv(9,x)

ww=scipy.special.jv(5,x)
www=scipy.special.jv(9,x)




plt.axis('off')

plt.plot(y,zz,c='r')
plt.plot(yy,zzz,linewidth=0.9)
plt.plot(v,u,linewidth=0.7,c='g')

plt.savefig("D:/temp9.png")
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-30,30,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(3,x)
zz=scipy.special.jv(5,x)

yy=scipy.special.jv(9,-x)
zzz=scipy.special.jv(7,x)


v=scipy.special.jv(7,x)
u=scipy.special.jv(9,x)

ww=scipy.special.jv(5,x)
www=scipy.special.jv(9,x)




plt.axis('off')

plt.plot(y,zz,c='r')
plt.plot(yy,zzz,linewidth=0.9)
plt.plot(v,u,linewidth=0.7)

plt.savefig("D:/temp10.png")
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import scipy 
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl


x=np.arange(-20,0,0.1)

y=scipy.special.jv(1,x)
z=scipy.special.jv(6,x)
zz=scipy.special.jv(5,x)
yy=scipy.special.jv(9,x)
ww=scipy.special.jv(8,x)

www=scipy.special.jv(6,x)*(-1)

u=scipy.special.jv(4,x)
v=scipy.special.jv(5,x)

o=scipy.special.jv(1,x)
p=scipy.special.jv(6,x)*(-1)

vv=scipy.special.jv(2,x)*(-1)-0.1
uu=scipy.special.jv(7,x)


plt.plot(v,u,c='r',linewidth=0.7)
plt.plot(yy,ww,c='w')
plt.plot(yy,www)
plt.plot(uu,vv,c='violet',linewidth=0.3)

plt.plot(o,p,linewidth=0.5)
plt.plot(yy,-u,linewidth=0.3,c='g')
plt.axis('off')

plt.savefig("D:/butter4.png")
plt.show()
